# %%
(1).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('youtube_dislike_dataset.csv')
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
(2).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
df.shape
# Out:
# (37422, 12)

# %%
(3).

# %%
df.isnull().sum()/len(df)*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
df.isnull().sum().comments
# Out:
# 158

# %%
df = df.dropna()
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
(4).

# %%
df.describe() #numerical_column
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df.describe(include="object")   #categorical_column
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37264  37264       37264
# unique                36617  28705       35479
# top     2020-10-16 04:00:10
# freq                      6   3808         587
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %%
(5).

# %%
df.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %%
df['published_at'] = pd.to_datetime(df['published_at'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37264 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  object
#  1   title          37264 non-null  object
#  2   channel_id     37264 non-null  object
#  3   channel_title  37264 non-null  object
#  4   published_at   37264 non-null  datetime64[ns]
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  object
#  10  description    37264 non-null  object
#  11  comments       37264 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.7+ MB

# %%
(6).

# %%
df['published_month_no'] = df['published_at'].dt.month
df['published_month_no']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month_no, Length: 37264, dtype: int32

# %%
(7).

# %%
df['published_month'] = df['published_at'].dt.strftime('%b')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
(8).

# %%
df.groupby('published_month')['published_month_no'].size().to_frame().reset_index().sort_values(by='published_month_no',ascending=False)
# Out:
#    published_month  published_month_no
# 10             Oct                4976
# 11             Sep                4854
# 9              Nov                4821
# 1              Aug                4250
# 2              Dec                3063
# 5              Jul                2331
# 6              Jun                2305
# 7              Mar                2248
# 3              Feb                2125
# 0              Apr                2119
# 4              Jan                2099
# 8              May                2073

# %%
(9).

# %%
df['video_id'].nunique()
# Out:
# 37264

# %%
df['channel_id'].nunique()
# Out:
# 10891

# %%
df['channel_title'].nunique()
# Out:
# 10813

# %%
df.nunique()
# Out:
# video_id              37264
# title                 36958
# channel_id            10891
# channel_title         10813
# published_at          36617
# view_count            37100
# likes                 32509
# dislikes               9038
# comment_count         13163
# tags                  28705
# description           35479
# comments              37264
# published_month_no       12
# published_month          12
# dtype: int64

# %%
(10).

# %%
channel_videocounts = df.groupby('channel_title').size().reset_index(name='video_counts')
channel_videocounts=channel_videocounts.sort_values(by='video_counts',ascending=False)
channel_videocounts.head(10)
# Out:
#             channel_title  video_counts
# 8223  Sky Sports Football           533
# 9098     The United Stand           301
# 1085             BT Sport           246
# 6310                  NBA           209
# 6347                  NFL           162
# 9780                  WWE           122
# 7809         SSSniperWolf            99
# 7810              SSundee            98
# 3037            FORMULA 1            87
# 6352                  NHL            86

# %%
channel_videocounts.tail(10)
# Out:
#          channel_title  video_counts
# 4790     Karikku Tuned             1
# 4787   Karen Bustillos             1
# 4786    Karen Aslanyan             1
# 4785           Karchez             1
# 4784     Karate Combat             1
# 4782      Kaptain Kuba             1
# 4777        Kanye West             1
# 4776    Kannur kitchen             1
# 4775    Kannada Cinema             1
# 10812             zoom             1

# %%
(11).

# %%
df.groupby('title')['likes'].sum().to_frame().reset_index().sort_values(by='likes',ascending=False)
# Out:
#                                                  title     likes
# 5233                     BTS () 'Dynamite' Official MV  31837675
# 5228                       BTS () 'Butter' Official MV  20649409
# 5065   BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V  17864527
# 5242                 BTS () 'Life Goes On' Official MV  16354127
# 5247          BTS () 'Permission to Dance' Official MV  15449003
# ...                                                ...       ...
# 33232        Virtual Pub Quiz, Live! Thursday 8th July       106
# 33189   Virtual Pub Quiz, Live! Saturday 12th December        97
# 28358                 Small Business Loans from OnDeck        29
# 31674           Tims For Good: A Taste Of The Familiar        28
# 19316                    Leading the Charge | Circle K        22
#
# [36958 rows x 2 columns]

# %%
max_likes_index = df['likes'].idxmax()
min_likes_index = df['likes'].idxmin()
max_likes_title = df.loc[max_likes_index,'title']
min_likes_title = df.loc[min_likes_index,'title']
print(max_likes_title)
print(min_likes_title)
# Out:
# BTS () 'Dynamite' Official MV
# Leading the Charge | Circle K

# %%
(12).

# %%
df.groupby('title')['dislikes'].sum().to_frame().reset_index().sort_values(by='dislikes',ascending=False)
# Out:
#                                                    title  dislikes
# 8241                 Cuties | Official Trailer | Netflix   2397733
# 5233                       BTS () 'Dynamite' Official MV   1814333
# 7252   Cardi B - WAP feat. Megan Thee Stallion [Offic...   1331181
# 2926   52 GAJ KA DAMAN | PRANJAL DAHIYA | AMAN JAJI |...   1259533
# 5065     BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V   1253187
# ...                                                  ...       ...
# 19361  Leicester v Gloucester | Wigglesworth Impresse...         7
# 35170  YONEX Thailand Open | Day 3: Saina Nehwal (IND...         7
# 19334  Leeds Rhinos vs Wakefield Trinity | Super Leag...         6
# 19777  Live Stream: Hampshire v Yorkshire - LV= Count...         4
# 31674             Tims For Good: A Taste Of The Familiar         3
#
# [36958 rows x 2 columns]

# %%
max_dislikes_index = df['dislikes'].idxmax()
min_dislikes_index = df['dislikes'].idxmin()
max_dislikes_title = df.loc[max_dislikes_index,'title']
min_dislikes_title = df.loc[min_dislikes_index,'title']
print(max_dislikes_title)
print(min_dislikes_title)
# Out:
# Cuties | Official Trailer | Netflix
# Tims For Good: A Taste Of The Familiar

# %%
(14).

# %%
january_videos = df[df['published_at'].dt.month == 1]
january_videos
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
len(january_videos)
# Out:
# 2099
